# %%
fp = '/home/aryan/Desktop/train.csv'
import pandas as p
import numpy as n
import matplotlib.pyplot as pt
# %matplotlib inline

# %%
df = p.read_csv(fp)
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
df.agg(['min','max','mean'])
# Out:
#           Id  MSSubClass MSZoning        LotArea Street LotShape LandContour  \
# min      1.0    20.00000  C (all)    1300.000000   Grvl      IR1         Bnk
# max   1460.0   190.00000       RM  215245.000000   Pave      Reg         Lvl
# mean   730.5    56.89726      NaN   10516.828082    NaN      NaN         NaN
#
#      Utilities LotConfig LandSlope      ...      EnclosedPorch   3SsnPorch  \
# min     AllPub    Corner       Gtl      ...            0.00000    0.000000
# max     NoSeWa    Inside       Sev      ...          552.00000  508.000000
# mean       NaN       NaN       NaN      ...           21.95411    3.409589
#
#      ScreenPorch    PoolArea       MiscVal     MoSold       YrSold  SaleType  \
# min     0.000000    0.000000      0.000000   1.000000  2006.000000       COD
# max   480.000000  738.000000  15500.000000  12.000000  2010.000000        WD
# mean   15.060959    2.758904     43.489041   6.321918  2007.815753       NaN
#
#       SaleCondition     SalePrice
# ...

# %% [markdown]
# # Data Cleaning performed

# %%
df = df.dropna(axis='columns')

# %%
df.describe()
# Out:
#                 Id   MSSubClass        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean    730.500000    56.897260   10516.828082     6.099315     5.575342
# std     421.610009    42.300571    9981.264932     1.382997     1.112799
# min       1.000000    20.000000    1300.000000     1.000000     1.000000
# 25%     365.750000    20.000000    7553.500000     5.000000     5.000000
# 50%     730.500000    50.000000    9478.500000     6.000000     5.000000
# 75%    1095.250000    70.000000   11601.500000     7.000000     6.000000
# max    1460.000000   190.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  \
# count  1460.000000   1460.000000  1460.000000  1460.000000  1460.000000
# mean   1971.267808   1984.865753   443.639726    46.549315   567.240411
# std      30.202904     20.645407   456.098091   161.319273   441.866955
# ...

# %%
df.agg(['min','max','mean'])
# Out:
#           Id  MSSubClass MSZoning        LotArea Street LotShape LandContour  \
# min      1.0    20.00000  C (all)    1300.000000   Grvl      IR1         Bnk
# max   1460.0   190.00000       RM  215245.000000   Pave      Reg         Lvl
# mean   730.5    56.89726      NaN   10516.828082    NaN      NaN         NaN
#
#      Utilities LotConfig LandSlope      ...      EnclosedPorch   3SsnPorch  \
# min     AllPub    Corner       Gtl      ...            0.00000    0.000000
# max     NoSeWa    Inside       Sev      ...          552.00000  508.000000
# mean       NaN       NaN       NaN      ...           21.95411    3.409589
#
#      ScreenPorch    PoolArea       MiscVal     MoSold       YrSold  SaleType  \
# min     0.000000    0.000000      0.000000   1.000000  2006.000000       COD
# max   480.000000  738.000000  15500.000000  12.000000  2010.000000        WD
# mean   15.060959    2.758904     43.489041   6.321918  2007.815753       NaN
#
#       SaleCondition     SalePrice
# ...

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 1349  1350          70       RM     5250   Pave      Reg         Lvl
# 1137  1138          50       RL     6342   Pave      Reg         Lvl
# 747    748          70       RM    11700   Pave      IR1         Lvl
# 304    305          75       RM    18386   Pave      Reg         Lvl
# 1132  1133          70       RM     9900   Pave      Reg         Lvl
# 630    631          70       RM     9000   Pave      Reg         Lvl
# 991    992          70       RM    17671   Pave      Reg         Lvl
# 106    107          30       RM    10800   Pave      Reg         Lvl
# 1416  1417         190       RM    11340   Pave      Reg         Lvl
# 945    946          50       RM     8820   Pave      Reg         Lvl
# 716    717          70       RM    10800   Pave      Reg         Bnk
# 185    186          75       RM    22950   Pave      IR2         Lvl
# 1292  1293          70       RM     6600   Pave      Reg         Lvl
# ...

# %%
for i in df.columns:
    print(df[i].unique())
# Out:
# [1350 1138  748 ...  158  763  379]
# [ 70  50  75  30 190  90  45  40  20  60  80  85 160 180 120]
# ['RM' 'RL' 'C (all)' 'RH' 'FV']
# [ 5250  6342 11700 ... 12220 12003 11394]
# ['Pave' 'Grvl']
# ['Reg' 'IR1' 'IR2' 'IR3']
# ['Lvl' 'Bnk' 'HLS' 'Low']
# ['AllPub' 'NoSeWa']
# ['Inside' 'Corner' 'FR2' 'FR3' 'CulDSac']
# ['Gtl' 'Mod' 'Sev']
# ['OldTown' 'Sawyer' 'IDOTRR' 'Edwards' 'BrkSide' 'ClearCr' 'Crawfor'
#  'SWISU' 'NAmes' 'SawyerW' 'Mitchel' 'Gilbert' 'Timber' 'NWAmes' 'CollgCr'
#  'BrDale' 'MeadowV' 'Veenker' 'NPkVill' 'Blueste' 'StoneBr' 'NoRidge'
#  'Somerst' 'Blmngtn' 'NridgHt']
# ['Norm' 'Feedr' 'Artery' 'RRAn' 'PosN' 'RRNn' 'RRAe' 'PosA' 'RRNe']
# ['Norm' 'PosA' 'Artery' 'Feedr' 'RRNn' 'RRAn' 'RRAe' 'PosN']
# ['1Fam' '2fmCon' 'Duplex' 'Twnhs' 'TwnhsE']
# ['2Story' '1.5Fin' '2.5Fin' '1Story' '2.5Unf' '1.5Unf' 'SLvl' 'SFoyer']
# [ 8  5  7  6  4 10  3  2  1  9]
# [5 8 7 9 4 6 2 3 1]
# [1872 1875 1880 1882 1885 1890 1892 1893 1898 1900 1904 1905 1906 1908
# ...

# %%
df = df.sort_values(by=['YearBuilt'])
